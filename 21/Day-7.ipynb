# %% [markdown]
# # **Day-7 of 2nd Challenge**

# %% [markdown]
# 1. Use *abc module*
#
# Create:
#
# - Abstract class `Shape`
#     - abstract method `area()`
#
# 👉 Tasks:
#
# - Try creating object of `Shape` (observe error)
# - Create child class `Rectangle` and implement `area()`

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Rectangle(Shape):
    def __init__(self, length, breadth):
        self.length=length
        self.breadth=breadth
    
    def area(self):
        return self.length*self.breadth

obj1=Rectangle(4, 3)
print(obj1.area())
obj2=Shape()
# Out:
# 12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 18
#      16 obj1=Rectangle(4, 3)
#      17 print(obj1.area())
# ---> 18 obj2=Shape()
#
# TypeError: Can't instantiate abstract class Shape without an implementation for abstract method 'area'

# %% [markdown]
# 2. Create abstract class `Vehicle`:
#
# abstract methods:
# - `start_engine()`
# - `stop_engine()`
#
# Create class `Car`:
#
# - implement both methods

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    @abstractmethod
    def start_engine(self):
        pass
    
    @abstractmethod
    def stop_engine(self):
        pass

class Car(Vehicle):
    def start_engine(self):
        return "Car engine started!"
    
    def stop_engine(self):
        return "Car engine stopped!!"

obj1=Car()
print(obj1.start_engine())
print(obj1.stop_engine())
# Out:
# Car engine started!
# Car engine stopped!!

# %% [markdown]
# 3. Create abstract class `Employee`:
#
# - constructor: `name`, `salary`
# - abstract method: `calculate_bonus()`
#
# Create:
#
# - `Manager` → bonus = 20% of salary
# - `Developer` → bonus = 10% of salary
#
# 👉 Create objects and print bonus

# %%
from abc import ABC, abstractmethod

class Employee(ABC):
    def __init__(self, name, salary):
        self.name=name
        self.salary=salary
    
    @abstractmethod
    def calculate_bonus(self):
        pass

class Manager(Employee):
    def calculate_bonus(self):
        return 0.20*self.salary

class Developer(Employee):
    def calculate_bonus(self):
        return 0.10*self.salary

obj1=Manager("Ashish", 100000)
obj2=Developer("Tanveer", 50000)

print(obj1.calculate_bonus())
print(obj2.calculate_bonus())
# Out:
# 20000.0
# 5000.0

# %% [markdown]
# 4. Using `Employee`, `Manager`, `Developer`:
#
# 👉 Create a list of employees
# 👉 Loop and call `calculate_bonus()`

# %%
employees=[Manager("krish", 50000), Developer("harsh", 20000), Manager("suryansh", 35000)]
for emp in employees:
    print(emp.name, "Bonus: ", emp.calculate_bonus())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 employees=[Manager("krish", 50000), Developer("harsh", 20000), Manager("suryansh", 35000)]
#       2 for emp in employees:
#       3     print(emp.name, "Bonus: ", emp.calculate_bonus())
#
# NameError: name 'Manager' is not defined

# %% [markdown]
# 5. Create abstract class `Payment`:
#
# - abstract method `pay(amount)`
#
# Create:
#
# `CreditCardPayment`
# `UPIPayment`
#
# 👉 Each should implement `pay()` differently
#
# 👉 Simulate:
#
# - making payments using different methods

# %%
from abc import ABC, abstractmethod

class Payment(ABC):
    @abstractmethod
    def pay(self, amount):
        pass

class CreditCardPayment(Payment):
    def pay(self, amount):
        return f"{amount} paid successfully via credit card!!"

class UPIPayment(Payment):
    def pay(self, amount):
        return f"{amount} paid successfully via UPI"
    
obj1=CreditCardPayment()
obj2=UPIPayment()

print(obj1.pay(25000))
print(obj2.pay(93000))
# Out:
# 25000 paid successfully via credit card!!
# 93000 paid successfully via UPI
