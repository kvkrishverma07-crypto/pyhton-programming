# %% [markdown]
# ## Introduction to pyhton

# %% [markdown]
# # PYTHON

# %% [markdown]
# # CHAPTER - 1

# %% [markdown]
# # "pyhton is an interpreted, object-orinted,high-level programming language with dynamic semantics  .
# 1- its high-level built in data structures.
# 2- its combined with dynamic typing and dynamic binding, mnake it very attractive for Rapid application development, as well as for  use a scripting or glue language to connec t existing components together.
# 3-  pyhton is to earn and have easy syntax emphasizes readability.
# 4-And it reduces the cost of programming maintenance.
# 5-python supports modules and packages.

# %% [markdown]
# # What is ineractive programming in pyhton? 5 MARKS.
#
# When we run a program derictly from terminal, and the output is instant. We dont need a helper command to run the script to run the code. its is called interactive programming in pyhton.

# %% [markdown]
# # What is script programming in pyhton ? 5 MARKS
#
# When we submit the code or script to the complier using a helper command. In the case of pyhton the terminal command is "pyhton -file name"

# %% [markdown]
# # INTERACTIVE PYTHON IN JUPYTER

# %%
a= 30
b=20 
print("What Is the product of a and b")
print(a*b)
# Out:
# What Is the product of a and b
# 600

# %% [markdown]
# # Script mode in jupyter NOtebook

# %%
a=40
b=40
print("sum of a+b")
print(a+b)
# Out:
# sum of a+b
# 80

# %% [markdown]
# In this script mode we to run code by terminal by enter the code in ternimal by command of your file.name.py

# %% [markdown]
# # Dynamic types in pyhton

# %% [markdown]
# pyhton as a script or language is what" dynamiclly typed", means the variable are declared ducring runtime and there datatype is not explicilty specified

# %% [markdown]
# what dynamic means here you are not specify the datatype for run the code like in eg;
#     in pyhton it is auto filled in pyhtonb

# %%
a =30

# %%
type(a)
# Out:
# int

# %% [markdown]
# # What is the command to check the data type ?

# %% [markdown]
# type() : give the data type of the vairable currently in use as you can see in above eg

# %% [markdown]
# # What are immutable data type ()?

# %% [markdown]
# The data types where values cannot be changed once assigned

# %% [markdown]
# Immutable data types

# %% [markdown]
# 1--> integer(int)
# 2--> floating point ( FLOAT)
# 3--> boolean ( bool)
# 4--> string (str)
# 5--> frozenset
# 6--> tuples

# %%
a="abcd"
print(a)
a="a6cd"
print(a)
# Out:
# abcd
# a6cd

# %% [markdown]
# # What is tuple?

# %% [markdown]
# it is also a immutable

# %% [markdown]
# # pyhton is an Object-Oriented language

# %% [markdown]
# In python, everything is an object
# that means these are all object:
# 1- int-10
# 2- string-"heelo"
# 3- lists-[1,2,3]
# 4- function- print, len
# 5- classes- str,list
# 6- even modules - math, os  sdfdbkbisbhufigiug

# %% [markdown]
# so in pyhton
# data + behavior are represented using objects.

# %% [markdown]
# ## what is an onject in pyhton?

# %% [markdown]
# definition ( theoretical )

# %% [markdown]
# . an onject a runtime entity that has:
# . indentity - unique memory reference (ID())
# . type - what kind of object it is (typed())
# . value / state - actual data stored

# %%
x = 10 
print(id(x))
print(type(x))
print(x)
# Out:
# 1641215427088
# <class 'int'>
# 10

# %% [markdown]
# internally
# 1-- 10 is an of object of class int
# 2-- int itself is also object (a class object)

# %% [markdown]
# ## Python's "class- based object system

# %% [markdown]
# In pyhton, every object is created from a class (type)
# example

# %%
name = "Vibhu"

# %% [markdown]
# Internally, python treats it as: "Vibhu" is an object its class is str That is why this works:
# str
# because str is an class object.

# %% [markdown]
# # How object are called/ accessed in pyhton

# %% [markdown]
# # dot operator (.) is attribute access

# %% [markdown]
# when you write :

# %%
"hello".upper()
# Out:
# 'HELLO'

# %% [markdown]
# pyhton interprets:
# 1- "hello" -- object
# 2-  upper  -- attribute (method) stored inside the class str
# So internally it becomes:

# %%
str.upper("hello")
# Out:
# 'HELLO'

# %% [markdown]
# # Meaning
# - methods are just functions stored inside a class, and python passes the object automatically.

# %% [markdown]
# # Built- in Functions vs Method ( Internal working)
# A) Built- in function ( Global/ Independent)
# example -

# %%
len("pyhton")
# Out:
# 6

# %% [markdown]
# ## Internal meaning:

# %% [markdown]
# Python searches len inside the built-in namespace.
#
# Built-ins live in:
#
# 1- __builtins__
# 2- builtins module
# So this is basically:

# %%
builtins.len("python")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 builtins.len("python")
#
# NameError: name 'builtins' is not defined

# %% [markdown]
# Built-in functions are not tied to one object.

# %% [markdown]
# ## Method (belongs to an object’s class)
# example

# %%
"python".upper()
# Out:
# 'PYTHON'

# %% [markdown]
# ## Internal meaning:
# Python does:
#
# 1- look at object type → str
# 2- find upper inside str
# 3- bind it with the object "python"
# 4- then call i

# %% [markdown]
# Equivalent internal call

# %%
str.upper("python")
# Out:
# 'PYTHON'

# %% [markdown]
# So, method = function that becomes bound to an object

# %% [markdown]
# ## Why Methods Feel Different?

# %% [markdown]
# Because in methods:
#
# Python automatically passes the object as the first argument
# That object is called:
#
# self (conventionally)

# %%
class Demo:
    def show(self):
        print("Hello")

d = Demo()
d.show()
# Out:
# Hello

# %% [markdown]
# nternally:
#
# Demo.show(d)
# So:
#
# d.show() is just a shortcut for Demo.show(d)

# %% [markdown]
# ## What Happens When You Write obj.method()?
# Example:

# %%
lst = [1, 2]
lst.append(5)
lst
# Out:
# [1, 2, 5]

# %% [markdown]
# Internal Steps:
# Python performs:
#
# Find the class: type(lst) → list
# Search append in list
# Bind it to lst
# Call it
# Equivalent:
#
# list.append(lst, 5)
# That’s why methods can modify the      object.

# %%
len("python")
# Out:
# 6

# %% [markdown]
# ## Why len() is a Function but append() is a Method?

# %% [markdown]
# Because of design:
#
# len() is general-purpose
# It works for many objects:
#
# list
# string
# tuple
# dict
# set
# Python calls the object’s internal     length rule:
#
# obj.__len__( )
# So:
#
# len(obj)
# Internally becomes:
#
# obj.__len__()
# len() is a built-in function that calls the method indirectly.

# %% [markdown]
# # Varriable - Native Python?
# ## A variable in any programming language is a named storage location in memory that holds data, and the value can change while the program runs.
#  # Naming and Using Variables:
# Guidelines
#
# 1- Variable names can contain only letters, numbers, and underscores. They can start with a letter or an underscore, but not with a number.For instance, you can call a variable message_1 but not 1_message.
# 2 - Spaces are not allowed in variable names, but underscores can be used to separate words in variable names. For example, greeting_message works, but greeting message will cause errors.
# 3 - Avoid using Python keywords and function names as variable names; that is, do not use words that Python has reserved for a particular programmatic purpose, such as the word print. (See “Python Keywords and Built-in Functions” on page 489.)
#  4- Variable names should be short but descriptive. For example, name is better than n, student_name is better than s_n, and name_length is better than length_of_persons_name.
# Be careful when using the lowercase letter l and the uppercase letter O because they could be confused with the numbers 1 and 0.

# %% [markdown]
# Note: The Python variables you’re using at this point should be lowercase. You won’t get errors if you use uppercase letters, but it’s a good idea to avoid using them for now.

# %% [markdown]
# Varriable Types?
# String : A string is a series of characters in a sequence, theye are written within "" or ''.

# %%
message = "Hello Python Crash Course reader!"
print(message)
# Out:
# Hello Python Crash Course reader!

# %% [markdown]
# # Python String Built-in Methods (Full List)
# # 1) Case Conversion Methods
# lower()
#
# Definition and Usage
# Return a copy of the string with all the cased characters converted to lowercase. For example:

# %%
a="PYTHON"
a.lower()
# Out:
# 'python'

# %% [markdown]
# upper()
#
# ## Definition and Usage
# Return a copy of the string with all the cased characters converted to uppercase. Note that s.upper().isupper() might be False if s contains uncased characters or if the Unicode category of the resulting character(s) is not “Lu” (Letter, uppercase), but e.g. “Lt” (Letter, titlecase).

# %%
"python".upper()
# Out:
# 'PYTHON'

# %% [markdown]
# title()
#
# ## Definition and Usage
# Return a title cased version of the string where words start with an uppercase character and the remaining characters are lowercase.

# %%
"python programming new".title()
# Out:
# 'Python Programming New'

# %% [markdown]
# capitalize()
#
# ## Definition and Usage
# The capitalize() Return a copy of the string with its first character capitalized and the rest lowercased.
#
# Changed in version 3.8: The first character is now put into titlecase rather than uppercase. This means that characters like digraphs will only have their first letter capitalized, instead of the full character

# %%
"python programming".capitalize()
# Out:
# 'Python programming'

# %% [markdown]
# swapcase()
#
# ## Definition and Usage
# The swapcase() method returns a string where all the upper case letters are lower case and vice versa.

# %%
"PyThOn".swapcase()
# Out:
# 'pYtHoN'

# %% [markdown]
# casefold() (stronger lower)
#
# ## Definition and Usage
# Return a casefolded copy of the string. Casefolded strings may be used for caseless matching.
#
# Casefolding is similar to lowercasing but more aggressive because it is intended to remove all case distinctions in a string. For example, the German lowercase letter 'ß' is equivalent to "ss". Since it is already lowercase, lower() would do nothing to 'ß'; casefold() converts it to "ss". For example:

# %%
"GERMAN ß".casefold()
# Out:
# 'german ss'

# %% [markdown]
# # 2) Remove Spaces / Cleanup
# strip(chars=None)
#
# ## Definition and Usage
# Return a copy of the string with the leading and trailing characters removed. The chars argument is a string specifying the set of characters to be removed. If omitted or None, the chars argument defaults to removing whitespace. The chars argument is not a prefix or suffix; rather, all combinations of its values are stripped:

# %%
"  hello      vibhu    ".strip()
# Out:
# 'hello      vibhu'

# %% [markdown]
# lstrip(chars=None)
#
# # Definition and Usage
# Return a copy of the string with leading characters removed. The chars argument is a string specifying the set of characters to be removed. If omitted or None, the chars argument defaults to removing whitespace. The chars argument is not a prefix; rather, all combinations of its values are stripped:

# %%
"  hello".lstrip()
# Out:
# 'hello'

# %% [markdown]
# rstrip(chars=None)
#
# # Definition and Usage
# Return a copy of the string with trailing characters removed. The chars argument is a string specifying the set of characters to be removed. If omitted or None, the chars argument defaults to removing whitespace. The chars argument is not a suffix; rather, all combinations of its values are stripped:

# %%
"hello   ".rstrip()
# Out:
# 'hello'

# %% [markdown]
# # Search & Find
# ## find(sub[, start[, end]])
# ### Definition and Usage
# The find() method searches for a substring inside a string and returns the index (position) of the first occurrence of that substring.
#
# It scans the string from left to right. If the substring is found, it returns the starting index of the match. If the substring does not exist in the string, it returns -1. Because it returns -1 instead of raising an error, find() is considered safer when you are not sure whether the substring exists.
#
# Optional start and end parameters can be used to restrict the search to a specific part of the string.
#
# ### Syntax
# string.find(sub, start, end)
# #### Return Value
# Returns an integer index (0-based)
# Returns -1 if not found

# %%
"python".find("th")
# Out:
# 2

# %%
"python".find("zz")
# Out:
# -1

# %%
"banana".find("a", 2)
# Out:
# 3

# %% [markdown]
# # rfind(sub[, start[, end]])
# ## Definition and Usage
# The rfind() method works like find(), but it searches from the right side of the string towards the left.
#
# Even though it searches from the right, the returned index is still based on the normal left-to-right indexing system. If the substring is found, it returns the highest index where the substring begins. If the substring is not found, it returns -1.
#
# This method is useful when you want to locate the last occurrence of a substring without raising an error.
#
# ### Syntax
# string.rfind(sub, start, end)
# #### Return Value
# Returns the last index where the substring starts
# Returns -1 if not found

# %%
"banana".rfind("a")
# Out:
# 5

# %%
"banana".rfind("x")
# Out:
# -1

# %% [markdown]
# ## index(sub[, start[, end]])
# ### Definition and Usage
# The index() method searches for a substring in a string and returns the index of the first occurrence, just like find().
#
# The major difference is error handling: if the substring is not found, index() raises a ValueError instead of returning -1.
#
# This method is useful in situations where the substring must exist, and if it does not, you want the program to fail immediately and clearly.
#
# ### Syntax
# string.index(sub, start, end)
# #### Return Value
# Returns an integer index (0-based)
# Raises ValueError if substring is not found

# %%
"python".index("th")
# Out:
# 2

# %%
"python".index("zz")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 "python".index("zz")
#
# ValueError: substring not found

# %% [markdown]
# ## rindex(sub[, start[, end]])
# ### Definition and Usage
# The rindex() method is the reverse version of index().
#
# It returns the index of the last occurrence of a substring in the string. If the substring is not found, it raises a ValueError.
#
# This method is useful when you want the last match and you want strict validation (meaning the substring must exist).
#
# #### Syntax
# string.rindex(sub, start, end)
# ### Return Value
# Returns the last index of the substring
# Raises ValueError if substring is not found

# %%
"banana".rindex("a")
# Out:
# 5

# %% [markdown]
# ## count(sub[, start[, end]])
# ### Definition and Usage
# The count() method counts how many times a substring occurs in the string.
#
# It counts only non-overlapping occurrences and returns the total number of matches. It does not change the original string.
#
# This method is useful when you want frequency information such as how many times a word, character, or pattern exists inside text.
#
# Optional start and end allow counting only inside a specific range.
#
# ### Syntax
# string.count(sub, start, end)
# #### Return Value
# Returns an integer count (0 or more)

# %%
"banana".count("a")
# Out:
# 3

# %%
"banana".count("an")
# Out:
# 2

# %% [markdown]
# ## startswith(prefix[, start[, end]])
# ### Definition and Usage
# The startswith() method checks whether a string begins with the given prefix.
#
# It returns True if the prefix matches the beginning of the string, otherwise False. It does not search the whole string, only the starting position.
#
# This method is very useful in validation, pattern checks, filtering file names, checking URL prefixes (http, https), and checking naming conventions.
#
# ### Syntax
# string.startswith(prefix, start, end)
# #### Return Value
# Returns True or False

# %%
"python".startswith("py")
# Out:
# True

# %%
"python".startswith("on")
# Out:
# False

# %% [markdown]
# ## endswith(suffix[, start[, end]])
# ### Definition and Usage
# The endswith() method checks whether a string ends with the given suffix.
#
# It returns True if the suffix matches the ending of the string, otherwise False. It does not scan the whole string; it only checks the end.
#
# This method is commonly used in file validation such as checking extensions (.txt, .csv, .pdf) and confirming fixed endings in naming rules.
#
# ### Syntax
# string.endswith(suffix, start, end)
# #### Return Value
# Returns True or False

# %%
"python".endswith("on")
# Out:
# True

# %%
"python".endswith("py")
# Out:
# False

# %% [markdown]
# # Numeric Data Types, Input & Output, Escape Sequences
# ## Topics Covered
#
# ## Numeric Data Types in Python
# Input & Output Functions
# Escape Sequences in Strings
# 1) Numeric Data Types in Python
# Python provides three main numeric data types:
#
# 1- int → Whole numbers (no decimal)
# 2- float → Decimal numbers (real numbers)
# 3- complex → Complex numbers like a + bj
# 4- Additionally, bool is also treated as a numeric type in Python.

# %%
a = 10
b = -99
c = 0

print("a =", a, "| type:", type(a))
print("b =", b, "| type:", type(b))
print("c =", c, "| type:", type(c))

print("a + b =", a + b)
print("a * 5 =", a * 5)
# Out:
# a = 10 | type: <class 'int'>
# b = -99 | type: <class 'int'>
# c = 0 | type: <class 'int'>
# a + b = -89
# a * 5 = 50

# %% [markdown]
# ## float (Floating Point)
# Floats are decimal numbers.
# Python floats are stored in binary floating format, so small precision issues may occur.

# %%
x = 10.5
y = -3.14

print("x =", x, "| type:", type(x))
print("y =", y, "| type:", type(y))
print("x + y =", x + y)
print("x * 2 =", x * 2)
# Out:
# x = 10.5 | type: <class 'float'>
# y = -3.14 | type: <class 'float'>
# x + y = 7.359999999999999
# x * 2 = 21.0

# %%
print("0.1 + 0.2 =", 0.1 + 0.2)
print("Is 0.1 + 0.2 equal to 0.3?", (0.1 + 0.2) == 0.3)
# Out:
# 0.1 + 0.2 = 0.30000000000000004
# Is 0.1 + 0.2 equal to 0.3? False

# %% [markdown]
# ## complex (Complex Numbers)
# Complex numbers are represented as:
#
# a + bj
# where:
#
# a = real part
# b = imaginary part
# j = √(-1) in Python

# %%
z = 2 + 3j

print("z =", z, "| type:", type(z))
print("Real part:", z.real)
print("Imaginary part:", z.imag)
# Out:
# z = (2+3j) | type: <class 'complex'>
# Real part: 2.0
# Imaginary part: 3.0

# %%
z1 = 1 + 2j
z2 = 3 + 4j

print("z1 =", z1)
print("z2 =", z2)
print("z1 + z2 =", z1 + z2)
print("z1 * z2 =", z1 * z2)
# Out:
# z1 = (1+2j)
# z2 = (3+4j)
# z1 + z2 = (4+6j)
# z1 * z2 = (-5+10j)

# %% [markdown]
# ## bool as Numeric Type
# In Python:
#
# True behaves like 1
# False behaves like 0

# %%
print("True + 5 =", True + 5)
print("False * 10 =", False * 10)
print("type(True) =", type(True))
print("int(True) =", int(True))
print("int(False) =", int(False))
# Out:
# True + 5 = 6
# False * 10 = 0
# type(True) = <class 'bool'>
# int(True) = 1
# int(False) = 0

# %% [markdown]
# ## Type Casting (Conversions)
# Python allows conversion between numeric types:
#
# 1- int("10") → 10
# 2- float("10") → 10.0
# 3- 4- complex(2, 5) → (2+5j)
# - bool(0) → False
# - bool(100) → True

# %%
s = "10"

i = int(s)
f = float(s)
comp = complex(2, 5)

print("s =", s, "| type:", type(s))
print("int(s) =", i, "| type:", type(i))
print("float(s) =", f, "| type:", type(f))
print("complex(2, 5) =", comp, "| type:", type(comp))

print("bool(0) =", bool(0))
print("bool(100) =", bool(100))
# Out:
# s = 10 | type: <class 'str'>
# int(s) = 10 | type: <class 'int'>
# float(s) = 10.0 | type: <class 'float'>
# complex(2, 5) = (2+5j) | type: <class 'complex'>
# bool(0) = False
# bool(100) = True

# %% [markdown]
# ## Useful Numeric Built-in Functions
# - -abs() → absolute value
# - -pow() → power
# - -round() → rounding
# - -max() → maximum value
# - -min() → minimum value

# %%
print("abs(-25) =", abs(-25))
print("pow(2, 5) =", pow(2, 5))
print("round(3.14159, 2) =", round(3.14159, 2))
print("max(10, 20, 5) =", max(10, 20, 5))
print("min(10, 20, 5) =", min(10, 20, 5))
# Out:
# abs(-25) = 25
# pow(2, 5) = 32
# round(3.14159, 2) = 3.14
# max(10, 20, 5) = 20
# min(10, 20, 5) = 5

# %% [markdown]
# Arithmetic Operators
# - + Addition
# - - Subtraction
# - * Multiplication
# - / Division (always float)
# - // Floor division
# - % Modulus (remainder)
# - ** Power

# %%
a = 90
b = 5
print("a =", a, "b =", b)
print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)
print("a // b =", a // b)
print("a % b =", a % b)
print("a ** b =", a ** b)
# Out:
# a = 90 b = 5
# a + b = 95
# a - b = 85
# a * b = 450
# a / b = 18.0
# a // b = 18
# a % b = 0
# a ** b = 5904900000

# %% [markdown]
# ## 2) Input & Output Functions
# input()
# - Takes user input from keyboard
# - Always returns a string by default
# ## print()
# - Displays output in console/notebook
# - Can use sep and end for formatting

# %%
name = input("Enter your name: ")
# print("Hello", name)

# %%
age = int(input("Enter age: "))
salary = float(input("Enter salary: "))
print("Age:", age, "| type:", type(age))
print("Salary:", salary, "| type:", type(salary))
# Out:
# Age: 19 | type: <class 'int'>
# Salary: 25000.0 | type: <class 'float'>

# %% [markdown]
# ## Multiple Inputs in One Line
# Using split() to take multiple values from one input line.

# %%
x, y = input("Enter two numbers: ").split()
print("x =", x, "| type:", type(x))
print("y =", y, "| type:", type(y))
# Out:
# x = 100 | type: <class 'str'>
# y = 200 | type: <class 'str'>

# %%
x, y = map(int, input("Enter two integers: ").split())
print("Sum =", x + y)
# Out:
# Sum = 10

# %% [markdown]
# ## Output with print()
# print() supports optional parameters:
#
# - sep → separator between values
# - end → what to print at the end

# %%
print(1, 2, 3)                      
print(1, 2, 3, sep="-")             
print("Hello", end=" ")
print("World")
# Out:
# 1 2 3
# 1-2-3
# Hello World

# %% [markdown]
# ## Output Formatting
# f-string (Recommended)
# Fast and clean formatting:
#
# 1- {value} for direct values
# 2- {value:.2f} for 2 decimal places

# %%
name = "Vibhu"
age = 38
score = 95.6789

print(f"Name: {name}, Age: {age}, Score: {score}")
print(f"Score (2 decimals): {score:.2f}")
# Out:
# Name: Vibhu, Age: 38, Score: 95.6789
# Score (2 decimals): 95.68

# %%
print("Name: {}, Age: {}".format(name, age))
print("Score: {:.2f}".format(score))
# Out:
# Name: Vibhu, Age: 38
# Score: 95.68

# %%
print("Name: %s Age: %d" % (name, age))
print("Score: %.2f" % score)
# Out:
# Name: Vibhu Age: 38
# Score: 95.68

# %% [markdown]
# 3) Escape Sequences in Python
# Escape sequences are special characters used in strings with \\.
#
# Common ones:
#
# 1- \\n → New Line
# 2-\\t → Tab space
# 3-\\\\ → Backslash
# 4-\\' → Single quote
# 5-\\" → Double quote
# 6-\\r → Carriage return
# 7-\\b → Backspace
# 8-\\a → Alert (beep)

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print("Name\tAge\tCity")
print("krish\t18\tDehradun")
# Out:
# Name	Age	City
# krish	18	Dehradun

# %%
print("C:\\Users\\krish\\Documents")
# Out:
# C:\Users\krish\Documents

# %%
print('It\'s Python')
print("He said \"Hello\"")
# Out:
# It's Python
# He said "Hello"

# %%
print('It\'s Python')
print("He said \"Hello\"")
# Out:
# It's Python
# He said "Hello"

# %%
print("Hello\rWorld")
# Out:
# World

# %%
print("Warning!\a")
# Out:
# Warning!

# %% [markdown]
# ## Raw Strings (Very Important for File Paths and Regex)
# Raw strings use r"" and ignore escape sequences.
#
# Useful in:
#
# 1-Windows paths
# 2-Regular expressions
# path1 = "C:\\newfolder\\test"
# path2 = r"C:\newfolder\test"
#
# print("Normal string:", path1)
# print("Raw string:", path2)
# Normal string: C:\newfolder\test
# Raw string: C:\newfolder\test
# Combined Practice Program (Interactive)
# This program takes user details and prints a structured output using:
#
# 1-input()
# 2-type casting
# 3-f-string formatting
# 4-escape sequences

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))
cgpa = float(input("Enter your CGPA: "))
print("\n----- Student Report -----")
print(f"Name:\t{name}")
print(f"Age:\t{age}")
print(f"CGPA:\t{cgpa:.2f}")
print("--------------------------")
# Out:
# ----- Student Report -----
# Name:	krish
# Age:	18
# CGPA:	9.00
# --------------------------

# %% [markdown]
# ## Tokens, Naming Conventions, Operators & Precedence, type() & id()
# Topics Covered
#
# Tokens in Python
# Naming Conventions (Identifiers)
# Operators in Python
# Operator Precedence & Associativity
# type() and id() functions
# Each section contains explanation + runnable code.
#
# ## Tokens in Python
# A token is the smallest meaningful unit in a Python program.
#
# Python source code is broken into tokens by the interpreter before execution.
#
# ### Main Categories of Tokens
# Keywords (reserved words)
# Identifiers (names of variables, functions, classes)
# Literals (fixed values like numbers, strings)
# Operators (symbols like +, -, ==)
# Delimiters / Separators ((), [], {}, :, , etc.)

# %% [markdown]
# ## 1. Keywords
# Keywords are reserved words with special meaning in Python.
# You cannot use keywords as variable names.
#
# Examples: if, else, for, while, def, class, return, True, None
#
# We can view all keywords using the keyword module.

# %%
import keyword

print("Total keywords:", len(keyword.kwlist))
print(keyword.kwlist)
# Out:
# Total keywords: 35
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## 2. Identifiers
# Identifiers are names you give to:
#
# variables
# functions
# classes
# modules
# Rules for identifiers
#
# Must start with a letter (A-Z or a-z) or underscore _
# Cannot start with a digit
# Can contain letters, digits, unders cores
# Case-sensitive: age, Age, AGE are different
# Cannot be a keyword

# %%
age = 25
_age = 30
age2 = 40

print(age, _age, age2)
# Out:
# 25 30 40

# %% [markdown]
# ## 3. Literals
# Literals are fixed values written directly in code.
#
# Types:
#
# Numeric: 10, 3.14, 2+3j
# String: "hello", 'python'
# Boolean: True, False
# None literal: None
# Collection literals: [1,2], (1,2), {1,2}, {"a":1}

# %%
n = 10
pi = 3.14
name = "krish"
flag = True
nothing = None
lst = [1, 2, 3]
tup = (1, 2)
st = {1, 2, 3}
dct = {"a": 1}

print(n, pi, name, flag, nothing, lst, tup, st, dct)
# Out:
# 10 3.14 krish True None [1, 2, 3] (1, 2) {1, 2, 3} {'a': 1}

# %% [markdown]
# ## 4. Operators (as tokens)
# Operators are symbols that perform operations on values. Examples:
#
# +, -, *, /
# ==, !=, <=
# and, or, not
# 5. Delimiters / Separators
# Delimiters are symbols that structure code.
#
# Common delimiters:
#
# () parentheses: function calls, grouping
# [] brackets: lists, indexing
# {} braces: dict/set
# : colon: blocks and slicing
# , comma: separate items
# . dot: attribute access

# %%
nums = [10, 20, 30]
print(nums[0])        
print(nums[0:2])      

data = {"name": "krish", "age": 38}  
print(data["name"])
# Out:
# 10
# [10, 20]
# krish

# %% [markdown]
# ## 2) Naming Conventions (Professional Python Style)
# Naming conventions make code readable and maintainable.
#
# Standard Conventions (PEP 8 style)
# Variables & functions: snake_case
# Constants: UPPER_CASE
# Classes: PascalCase
# Protected (internal use): _single_leading_underscore
# Strongly "private" (name mangling):         __double_leading_underscore
# Special (magic/dunder): __init__, __str__

# %%
student_name = "Vibhu"
total_marks = 95

def calculate_average(a, b):
    return (a + b) / 2

# Constants (UPPER_CASE)
PI = 3.14159
MAX_RETRIES = 3

# Class (PascalCase)
class StudentProfile:
    pass

# Internal use
_internal_cache = {}

# Name mangling (for class members)
class BankAccount:
    def __init__(self):
        self.__balance = 0  # name-mangled

print(student_name, total_marks, calculate_average(10, 20), PI, MAX_RETRIES)
# Out:
# Vibhu 95 15.0 3.14159 3

# %% [markdown]
# ## Good vs Bad Names
# Good names
#
# total_students
# is_valid_email
# compute_loss
# Bad names
#
# x1, temp2, aa (unless short loop variables)
# data12345 (unclear meaning)
# Naming should reflect:
#
# purpose
# meaning
# units (if needed): time_seconds, distance_km

# %% [markdown]
# ## 3) Operators in Python
# An operator performs an operation on one or more operands (values).
#
# Categories
# Arithmetic
# Comparison (Relational)
# Assignment
# Logical
# Bitwise
# Membership
# Identity

# %%
a, b = 10, 3
print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)     # float division
print("a // b =", a // b)   # floor division
print("a % b =", a % b)     # remainder
print("a ** b =", a ** b)
# Out:
# a + b = 13
# a - b = 7
# a * b = 30
# a / b = 3.3333333333333335
# a // b = 3
# a % b = 1
# a ** b = 1000

# %% [markdown]
# ## 2. Comparison Operators
# ==  !=  <  >  <=  >=
#
# They return Boolean (True or False).

# %%
x, y = 5, 10
print("x == y:", x == y)
print("x != y:", x != y)
print("x < y:", x < y)
print("x <= y:", x <= y)
print("x > y:", x > y)
print("x >= y:", x >= y)
# Out:
# x == y: False
# x != y: True
# x < y: True
# x <= y: True
# x > y: False
# x >= y: False

# %% [markdown]
# ## 3. Assignment Operators
# =  +=  -=  *=  /=  //=  %=  **=
#
# They update a variable.

# %%
n = 10
n += 5
print("After n += 5:", n)

n *= 2
print("After n *= 2:", n)

n //= 3
print("After n //= 3:", n)
# Out:
# After n += 5: 15
# After n *= 2: 30
# After n //= 3: 10

# %% [markdown]
# ## 4. Logical Operators
# and, or, not
#
# They operate on boolean expressions.

# %%
age = 20
has_id = True

print("Eligible?", age >= 18 and has_id)
print("Either condition true?", age >= 18 or has_id)
print("Negation:", not has_id)
# Out:
# Eligible? True
# Either condition true? True
# Negation: False

# %% [markdown]
# ## 5. Bitwise Operators
# Used with integers at binary level.
#
# & AND
# | OR
# ^ XOR
# ~ NOT
# << Left shift
# >> Right shift

# %%
print("a & b =", a & b)   # 010 -> 2
print("a | b =", a | b)   # 111 -> 7
print("a ^ b =", a ^ b)   # 101 -> 5
print("~a =", ~a)         # bitwise NOT (two's complement)
print("a << 1 =", a << 1) # 1100 -> 12
print("a >> 1 =", a >> 1) # 11 -> 3
# Out:
# a & b = 2
# a | b = 11
# a ^ b = 9
# ~a = -11
# a << 1 = 20
# a >> 1 = 5

# %% [markdown]
# ## 6. Membership Operators
# Used to check presence inside a sequence/collection.
#
# in
# not in

# %%
nums = [10, 20, 30]
print(20 in nums)
print(99 not in nums)

text = "python programming"
print("python" in text)
# Out:
# True
# True
# True

# %% [markdown]
# ## 7. Identity Operators
# Used to check whether two references point to the same object in memory.
#
# is
# is not
# Important: is checks identity (same object), not equality of values.

# %%
a = [1, 2, 3]
b = [1, 2, 3]
c = a

print("a == b:", a == b)     # values equal
print("a is b:", a is b)     # different objects
print("a is c:", a is c)     # same object
# Out:
# a == b: True
# a is b: False
# a is c: True

# %% [markdown]
# ## 4) Operator Precedence & Associativity
# Precedence decides which operator is evaluated first in an expression.
#
# General ideas:
#
# () parentheses have highest precedence
# ** (power) is high precedence and is right-associative
# * / // % come before + -
# Comparisons come after arithmetic
# not > and > or
# When in doubt, use parentheses to make intention clear.

# %%
print(2 + 3 * 4)      # 2 + (3*4) = 14

# Parentheses override precedence
print((2 + 3) * 4)    # 20

# Power has higher precedence than unary minus
print(-3 ** 2)        # -(3**2) = -9
print((-3) ** 2)      # 9

# Right associativity of **
print(2 ** 3 ** 2)    # 2 ** (3 ** 2) = 2 ** 9 = 512
# Out:
# 14
# 20
# -9
# 9
# 512

# %% [markdown]
# ## Logical precedence: not, and, or
# Evaluation order:
#
# not
# and
# or

# %%
a = True
b = False
c = False

# not has higher precedence than and/or
print(not a and b)     # (not a) and b

# and before or
print(a or b and c)    # a or (b and c)
# Out:
# False
# True

# %% [markdown]
# ## 5) type() and id() in Python
# type(object)
# Returns the data type (class) of a value/object.
#
# id(object)
# Returns a unique identity number for the object (often its memory address in CPython). Useful for understanding:
#
# object identity
# mutability
# references

# %%
print(type(10))
print(type(10.5))
print(type("python"))
print(type([1, 2, 3]))
print(type({"a": 1}))
print(type(True))
print(type(None))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>
# <class 'bool'>
# <class 'NoneType'>

# %%
x = 10
y = 10
z = 11

print("id(x) =", id(x))
print("id(y) =", id(y))
print("id(z) =", id(z))

print("x is y?", x is y)
print("x == y?", x == y)
# Out:
# id(x) = 2712687084048
# id(y) = 2712687084048
# id(z) = 2712687084080
# x is y? True
# x == y? True

# %% [markdown]
# ## id() and Mutability (Very Important)
# Immutable types: int, float, str, tuple
# If you "change" them, Python creates a new object.
# Mutable types: list, dict, set
# They can be modified in-place without creating a new object.

# %%
a = 100
print("Before change:", a, "id:", id(a))

a = a + 1
print("After change:", a, "id:", id(a))
# Out:
# Before change: 100 id: 2712687086928
# After change: 101 id: 2712687086960

# %%
lst = [1, 2, 3]
print("Before change:", lst, "id:", id(lst))

lst.append(4)
print("After append:", lst, "id:", id(lst))  # same id
# Out:
# Before change: [1, 2, 3] id: 2712768781504
# After append: [1, 2, 3, 4] id: 2712768781504

# %% [markdown]
# ## Equality (==) vs Identity (is)
# == checks whether values are equal
# is checks whether two variables point to the same object
# Use:
#
# == for value comparison
# is for checking None or object identity

# %%
a = [1, 2, 3]
b = [1, 2, 3]
c = a

print("a == b:", a == b)  # True (values same)
print("a is b:", a is b)  # False (different objects)
print("a is c:", a is c)  # True (same object)

val = None
print("val is None:", val is None)  # recommended way
# Out:
# a == b: True
# a is b: False
# a is c: True
# val is None: True

# %% [markdown]
# ##  Quick Practice (Run and Observe)
# Try predicting output before running the cell:
#
# operator precedence
# identity vs equality
# id changes for immutable objects

# %%
expr1 = 5 + 2 * 3 ** 2
expr2 = (5 + 2) * (3 ** 2)

print("expr1 =", expr1)
print("expr2 =", expr2)

x = "hello"
y = "he" + "llo"
print("x == y:", x == y)
print("x is y:", x is y)   # may vary due to interning, observe

m = [1, 2]
n = m
n.append(3)
print("m:", m)
print("n:", n)
print("m is n:", m is n)
# Out:
# expr1 = 23
# expr2 = 63
# x == y: True
# x is y: True
# m: [1, 2, 3]
# n: [1, 2, 3]
# m is n: True

# %% [markdown]
# # CHAPTER -2

# %% [markdown]
# ## 1) Initialization
# Strings are immutable sequences of characters.
#
# Create using:
#
# Single quotes: 'hello'
# Double quotes: "hello"
# Triple quotes (multi-line): """hello"""

# %%
s1 = 'Python'
s2 = "Data Science"
s3 = """Line1
Line2"""

print(s1)
print(s2)
print(s3)
# Out:
# Python
# Data Science
# Line1
# Line2

# %% [markdown]
# ## 2) Operators on strings
# + concatenation, * repetition
# in membership
# comparison uses lexicographic order

# %%
print("Py" + "thon")      # 'Python'
print("ha" * 3)           # 'hahaha'
print("a" in "cat")       # True
print("abc" < "abd")      # True
# Out:
# Python
# hahaha
# True
# True

# %% [markdown]
# ## 3) Indexing (0-based)

# %%
s = "Python"
print(s[0])   # 'P'
print(s[-1])  # 'n'

print(s[len(s)-1])
# print(s[len(s)])
# Out:
# P
# n
# n

# %% [markdown]
# ## 4) Slicing

# %%
s = "Python"
print(s[1:4])    # 'yth'
print(s[:3])     # 'Pyt'
print(s[3:])     # 'hon'
print(s[5:1:-1])   # 'nohtyP'
# Out:
# yth
# Pyt
# hon
# noht

# %% [markdown]
# ## 5) split()

# %%
print("one two three".split())         # ['one','two','three']
print("2026-02-10".split("-"))
# Out:
# ['one', 'two', 'three']
# ['2026', '02', '10']

# %% [markdown]
# ## Lecture 2 — Lists
# 1) Initialization
# Lists are mutable, ordered collections.

# %%
L = [10, 20, 30]
mixed = [1, "A", 3.5, True]
empty = []
print(L)
print(mixed)
print(empty)
# Out:
# [10, 20, 30]
# [1, 'A', 3.5, True]
# []

# %% [markdown]
# ## 2) Common methods
# append(x), extend(iterable), insert(i,x)
# remove(x), pop(i), clear()
# index(x), count(x)
# sort(), reverse()

# %%
L = [3, 1, 2]
L.append(5)         # [3,1,2,5]
print(L)
L.sort()            # [1,2,3,5]
print(L)
L.pop(2)
print(L)
L.remove(5)
print(L)
L.clear()
print(L)
# Out:
# [3, 1, 2, 5]
# [1, 2, 3, 5]
# [1, 2, 5]
# [1, 2]
# []

# %% [markdown]
# ## 3) Operations
# Concatenation, repetition, membership
# indexing/slicing same as string

# %%
print([1,2] + [3,4])      # [1,2,3,4]
print([0]*4)              # [0,0,0,0]
print(2 in [1,2,3])
# Out:
# [1, 2, 3, 4]
# [0, 0, 0, 0]
# True

# %% [markdown]
# ## 4) List comprehension
# Compact way to build lists

# %%
for item in iterator:
    return item*item
# Out:
#   Cell In[46], line 2
#     return item*item
#     ^
# SyntaxError: 'return' outside function

# %%
squares = [x*x for x in range(1,6)]
evens = [x for x in range(10) if x%2==0]
pairs = [(x,y) for x in [1,2] for y in [3,4,6]]
print(squares)
print(evens)
print(pairs)
# Out:
# [1, 4, 9, 16, 25]
# [0, 2, 4, 6, 8]
# [(1, 3), (1, 4), (1, 6), (2, 3), (2, 4), (2, 6)]

# %% [markdown]
# ## 5) Nesting
# list of lists ( 2D STRUCTURE)

# %%
mat = [[1,2,3],[4,5,6]]
print(mat[1][2])   # 6
# Out:
# 6

# %% [markdown]
# ## Lecture 3 — Tuples
# 1) Initialization
# Tuples are immutable ordered collections.

# %%
t1 = (1,2,3)
t2 = 1,2,3          # parentheses optional
t3 = (5,)           # single element tuple needs comma

print(t1)
print(t2)
print(t3)
# Out:
# (1, 2, 3)
# (1, 2, 3)
# (5,)

# %% [markdown]
# ## 2) Operations
# indexing/slicing, +, *, in

# %%
t = (10,20,30,40)
print(t[1])      # 20
print(t[1:3])    # (20,30)
# Out:
# 20
# (20, 30)

# %% [markdown]
# ## 3) Methods (limited)
# count(x), index(x)

# %%
print((1,2,2,3).count(2))  # 2
print((1,2,2,3).index(2))
# Out:
# 2
# 1

# %% [markdown]
# ## 4) Nesting

# %%
T = ((1,2),(3,4))
print(T[1][0])  # 3
# Out:
# 3

# %% [markdown]
# ## 5) List vs Tuple
# Feature	   List	    Tuple
# Mutability	Mutable	Immutable
# Speed	     Slower	 Faster
# Methods	      Many	Few
# Use case	dynamic data	fixed records / keys

# %% [markdown]
# ## Lecture 4 — Sets & Dictionaries
# A) Sets
# 1) Initialization
# Sets are unordered, unique elements.

# %%
S = {1,2,3}
S2 = set([1,2,2,3])   # {1,2,3}
empty_set = set()     # {} is empty dict, not set
print(S)
print(S2)
print(empty_set)
# Out:
# {1, 2, 3}
# {1, 2, 3}
# set()

# %% [markdown]
# ## 2) Methods / Operations
# add, remove, discard, pop
# union(|), intersection(&), difference(-), symmetric_difference(^)

# %%
A = {1,2,3}
B = {3,4,5}
print(A)
print(B)
print(A | B)   # {1,2,3,4,5}
print(A & B)   # {3}
print(A - B)
# Out:
# {1, 2, 3}
# {3, 4, 5}
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}

# %% [markdown]
# ## B) Dictionaries
# 1) Initialization
# Key–value mapping. Keys must be hashable (immutable types).

# %%
d = {"name":"Vibhu", "age":38}
d2 = dict(a=1, b=2)
print(d)
print(d2)
# Out:
# {'name': 'Vibhu', 'age': 38}
# {'a': 1, 'b': 2}

# %% [markdown]
# ## 2) Common operations/methods
# Access: d[key], safe access: d.get(key, default)
# Insert/update: d[key] = value, update()
# Remove: pop(key), popitem(), del d[key]
# Views: keys(), values(), items()

# %%
print(d)
d["age"] = 39
print(d)
print(d.get("city", "NA"))
# Out:
# {'name': 'Vibhu', 'age': 38}
# {'name': 'Vibhu', 'age': 39}
# NA

# %% [markdown]
# ## 3) Nesting

# %%
student = {
  "name":"A",
  "marks":{"math":90, "python":95}
}
student["marks"]["python"]
# Out:
# 95

# %% [markdown]
# ## 4) Sorting & typecasting
# Sort dict by keys or by values using sorted()

# %%
a="LKDJFHASDFJHSAD"
sorted(a)
# Out:
# ['A', 'A', 'D', 'D', 'D', 'F', 'F', 'H', 'H', 'J', 'J', 'K', 'L', 'S', 'S']

# %%
d = {"b":2, "a":5, "c":1}
print(sorted(d))                       # ['a','b','c']
print(sorted(d.items()))               # [('a',5),('b',2),('c',1)]
print(sorted(d.items(), key=lambda x: x[1]))  # by value
# Out:
# ['a', 'b', 'c']
# [('a', 5), ('b', 2), ('c', 1)]
# [('c', 1), ('b', 2), ('a', 5)]

# %% [markdown]
# ## Lecture 5 — Functions
# 1) User-defined functions

# %%
def add(a, b):
    return a + b

# %% [markdown]
# ## 2) Parameters
# positional, keyword, default, variable-length

# %%
def f(a, b=10):
    return a+b

def g(*args):        # tuple of positional args
    return sum(args)

def h(**kwargs):     # dict of keyword args
    return kwargs

# %% [markdown]
# ## 3) Documentation (docstring)

# %%
def area_circle(r):
    """Return area of circle for radius r."""
    return 3.14159 * r * r

area_circle.__doc_

sorted.__doc__
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 5
#       2     """Return area of circle for radius r."""
#       3     return 3.14159 * r * r
# ----> 5 area_circle.__doc_
#       7 sorted.__doc__
#
# AttributeError: 'function' object has no attribute '__doc_'

# %% [markdown]
# ## 4) Scope
# Local, Enclosing, Global, Built-in (LEGB)

# %%
x = 10
def foo():
    x = 5
    return x

# %%
x=10
print(foo())
print(x)
# Out:
# 5
# 10

# %% [markdown]
# ## 5) Recursion

# %% [markdown]
# Function calls itself; must have base case

# %%
def fact(n):
    if n == 0:
        return 1
    return n * fact(n-1)

# %%
print(fact(4))
# Out:
# 24

# %% [markdown]
# ## Lecture 6 — Advanced Functions
# 1) lambda

# %% [markdown]
# Anonymous function.

# %%
print(square(2))
# Out:
# 4

# %%
def square(x):
    return x*x

# %%
l =[1,2,3,4]

# %%
def square(x):
    return x*x
new_list =[]
for each in l:
    new_list.append(square(each))

# %%
[x*x for x in l]
list(map(lambda x : x*x, l))
# Out:
# [1, 4, 9, 16]

# %%
def square(number):
    return number * number

numbers = [1, 2, 3, 4, 5]

# Map the custom square function to the list
squared_numbers = map(square, numbers)

print(list(squared_numbers))
# Output: [1, 4, 9, 16, 25]
# Out:
# [1, 4, 9, 16, 25]

# %%
list(map(square, l))
# Out:
# [1, 4, 9, 16]

# %% [markdown]
# ## 2) map()
# Apply a function to every element.

# %%
nums = [1,2,3]
list(map(lambda x: 100/x, nums))  # [1,4,9]
# Out:
# [100.0, 50.0, 33.333333333333336]

# %% [markdown]
# ## 3) filter()

# %% [markdown]
# Keep only elements satisfying condition.

# %%
nums = [1,2,3,4,5]
list(filter(lambda x: x%2==0, nums))  # [2,4]
# Out:
# [2, 4]

# %% [markdown]
# ## 4) Inner functions + returning functions

# %%
def outer(msg):
    def inner():
        return msg.upper()
    return inner

f = outer("hello")
print(f)
print(f())   # 'HELLO'
# Out:
# <function outer.<locals>.inner at 0x000002779EAE6A70>
# HELLO

# %%
outer("hellp")()
# Out:
# 'HELLP'

# %% [markdown]
# ## 5) Passing collections/functions

# %%
def apply_twice(f, x):
    return f(f(x))

apply_twice(lambda a: a+1, 5)
# Out:
# 7

# %% [markdown]
# ## Lecture 7 — Mutability in functions + Applications + Doubts
# 1) Mutable vs Immutable behavior
# Immutable types: int, float, str, tuple Mutable types: list, dict, set
#
# Key idea:
# If you modify a mutable object inside a function, the caller sees it.
# If you “modify” immutable objects, you actually create a new object.

# %%
def change_num(x):
    x = x + 1

def change_list(L):
    L.append(99)

a = 10
change_num(a)
print(a)     # 10 (unchanged)

L = [1,2]
change_list(L)
print(L)     # [1,2,99] (changed)
# Out:
# 10
# [1, 2, 99]
