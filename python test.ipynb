# %% [markdown]
# ## python class test 2

# %% [markdown]
# Q-1

# %%
class student:
    school_name = "upes"
    def __init__(self, name, age):
        self.name = name 
        self.age = age
s1 = student("krish", 18)
s2 = student( "riya", 17)
print(f"school: { s1.school_name}")
print(f"student 1: { s1.name} {s1.age}")
print(f"student 2: { s2.name} {s2.age}")
# Out:
# school: upes
# student 1: krish 18
# student 2: riya 17

# %% [markdown]
# ## q-2

# %%
class Employee:
    company ="ABC LTD"
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
    def show_details(self):
        print(f"Name:{self.name},Salary:{self.salary},company:{Employeee.company}")
        print(f"{self.name},{self.salary},{employee.company}")
    
    @ classmethod   
    def change (cls,new_name):
        cls.company = new_name

    s1 = employee("krish",10000)
    s2 = employee("riya",50000)

    print("Before chnaging company:")
        emp1.show_details()
        emp2.show_details()
      Employee.change_change("XYZ")
      print("\nAFTER CHNAGING COMPANY:")
        emp1.show_details()
        emp2.show_details()
# Out:
#   File <tokenize>:20
#     Employee.change_change("XYZ")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# q- 3

# %%
class mathhelper:
    @staticmethod
    def is_even(num):
        return num%2 ==0
print(mathhelper.is_even(8)) 
print( mathhelper.is_even(11))
# Out:
# True
# False

# %% [markdown]
# q-6

# %%
class student:
    def __init__(self,name,price):
        self.name = name
        self.price = price
    def __str__(self):
        return f"name of product is {self.name} and price {self.price}"
    def __add__(self,other):
        return self.price+other.price
    def __eq__(self,other):
        return self.price == other.price

p1 = student("laptop", 50000)
p2 = student( " phone", 30000)
p3 = student ( " tablet", 50000)
print(p1)
print(" total price __add__", p1+p2)
print( " both the value are wq __eq__", p1==p2)
# Out:
# name of product is laptop and price 50000
#  total price __add__ 80000
#  both the value are wq __eq__ False

# %% [markdown]
# q-4
